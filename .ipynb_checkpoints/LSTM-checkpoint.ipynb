# %% [markdown]
# * [Notebook](https://github.com/salgo60/MagnusFilthfyRich/blob/main/LSTM.ipynb)
# * [Test this Notebook](https://github.com/shubham-kothari/Stock-Price-Prediction-TSLA-using-LSTM/blob/master/Stock%20Price%20Prediction%20-%20TSLA.ipynb)
# * LSTM [Long short-term memory](https://en.wikipedia.org/wiki/Long_short-term_memory)
#   * [LSTM implementation explained](https://apaszke.github.io/lstm-explained.html)

# %%
import yfinance as yf    ## yahoo finance for stock data
import numpy as np      
import pandas as pd
import seaborn as sns    ## for Vizualization
import matplotlib.pyplot as plt           ## for Vizualization
from sklearn.preprocessing import MinMaxScaler   ## For scaling the data

from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout   ## importing layers of Neural network
from keras.callbacks import ModelCheckpoint     ## imporing modelcheck pointer
from keras.losses import MSE                  ## importing error function
from keras.optimizers import Adam              ## importing optimizer
from keras.activations import relu           ## importing activation function
import os

sns.set()

# %%
import matplotlib.pyplot as plt
df = yf.download('TSLA','2010-06-29','2020-01-25',interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df1 = df.copy()

# %%
df.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %% [markdown]
# ## Preprocessing and Feature Extraction
# I will be predicting the opening of TSLA stock

# %%
df = df['Open'].values
print("Total No. of days of TSLA's Stocks :",df.shape[0])
# Out:
# Total No. of days of TSLA's Stocks : 2410

# %% [markdown]
# Splitting the data into train test split¶

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8)-50:])
print('Training stock :',dataset_train.shape[0],'days')
print('Test stock :',dataset_test.shape[0],'days')
# Out:
# Training stock : 1928 days
# Test stock : 532 days

# %% [markdown]
# ### Scaling the data
# a) Train Data

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset_train = scaler.fit_transform(dataset_train.reshape(-1, 1))

# %% [markdown]
# b) Test Data

# %%
dataset_test = scaler.transform(dataset_test.reshape(-1, 1))

# %%
def create_dataset(df,n):
    '''
    Function to prepare data for the LSTM
    
    '''
    
    x = []
    y = []
  
    for i in range(n, df.shape[0]):
        x.append(df[i-n:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return x,y

# %%
x_train, y_train = create_dataset(dataset_train,50)

# %%
x_test, y_test = create_dataset(dataset_test,50)

# %% [markdown]
# ### Reshape features for LSTM Layer

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
print('Training data shape',x_train.shape)
print('Test data shape',x_test.shape)
# Out:
# Training data shape (1878, 50, 1)
# Test data shape (482, 50, 1)

# %% [markdown]
# ## Building model

# %%
model = Sequential()

model.add(LSTM(units=96, 
               return_sequences=True,
               input_shape=(x_train.shape[1], 1)))

model.add(Dropout(0.2))

model.add(LSTM(units=96, 
               return_sequences=True))

model.add(Dropout(0.2))

model.add(LSTM(units=96, 
               return_sequences=True))

model.add(Dropout(0.2))

model.add(LSTM(units=96))

model.add(Dropout(0.2))

model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 50, 96)            37632
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50, 96)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50, 96)            74112
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 50, 96)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 50, 96)            74112
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50, 96)            0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 96)                74112
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 97
# =================================================================
# Total params: 260,065
# Trainable params: 260,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=MSE, optimizer=Adam())

# %%
checkpointer = ModelCheckpoint(filepath='tesla.stock_prediction.hdf5',save_best_only=True,verbose=1)

callbacks = [checkpointer]

# %%
history = model.fit(x_train,y_train,batch_size=32,epochs=70,verbose=1,callbacks=[checkpointer],validation_split=0.05)
# Out:
# Epoch 1/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 00001: val_loss improved from inf to 0.00294, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 5s 90ms/step - loss: 0.0225 - val_loss: 0.0029
# Epoch 2/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00002: val_loss improved from 0.00294 to 0.00279, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 72ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 3/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00003: val_loss did not improve from 0.00279
# 56/56 [==============================] - 4s 74ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 4/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00004: val_loss improved from 0.00279 to 0.00255, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 73ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 5/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00005: val_loss improved from 0.00255 to 0.00243, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 72ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 6/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00006: val_loss improved from 0.00243 to 0.00242, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 73ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 7/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00007: val_loss improved from 0.00242 to 0.00209, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 8/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00008: val_loss did not improve from 0.00209
# 56/56 [==============================] - 4s 74ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 9/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00009: val_loss did not improve from 0.00209
# 56/56 [==============================] - 5s 96ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 10/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00010: val_loss did not improve from 0.00209
# 56/56 [==============================] - 4s 78ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 11/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00011: val_loss did not improve from 0.00209
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 12/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00012: val_loss did not improve from 0.00209
# 56/56 [==============================] - 5s 88ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 13/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00013: val_loss did not improve from 0.00209
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 14/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00014: val_loss improved from 0.00209 to 0.00182, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 15/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00015: val_loss did not improve from 0.00182
# 56/56 [==============================] - 4s 73ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 16/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00016: val_loss did not improve from 0.00182
# 56/56 [==============================] - 4s 79ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 17/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00017: val_loss did not improve from 0.00182
# 56/56 [==============================] - 4s 75ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 18/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00018: val_loss did not improve from 0.00182
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 19/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00019: val_loss improved from 0.00182 to 0.00156, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 77ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 20/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00020: val_loss did not improve from 0.00156
# 56/56 [==============================] - 4s 75ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 21/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00021: val_loss improved from 0.00156 to 0.00138, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 78ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 22/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00022: val_loss did not improve from 0.00138
# 56/56 [==============================] - 4s 77ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 23/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00023: val_loss did not improve from 0.00138
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 24/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00024: val_loss did not improve from 0.00138
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 25/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00025: val_loss improved from 0.00138 to 0.00135, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 26/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00026: val_loss improved from 0.00135 to 0.00116, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 27/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00027: val_loss did not improve from 0.00116
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 28/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00028: val_loss improved from 0.00116 to 0.00101, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 29/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00029: val_loss did not improve from 0.00101
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 30/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00030: val_loss improved from 0.00101 to 0.00100, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 78ms/step - loss: 0.0013 - val_loss: 9.9947e-04
# Epoch 31/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00031: val_loss did not improve from 0.00100
# 56/56 [==============================] - 4s 77ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 32/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00032: val_loss did not improve from 0.00100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 33/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00033: val_loss improved from 0.00100 to 0.00087, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0014 - val_loss: 8.7367e-04
# Epoch 34/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00034: val_loss did not improve from 0.00087
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0013 - val_loss: 8.7921e-04
# Epoch 35/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00035: val_loss improved from 0.00087 to 0.00077, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0012 - val_loss: 7.6557e-04
# Epoch 36/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00036: val_loss did not improve from 0.00077
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 37/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00037: val_loss did not improve from 0.00077
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 38/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00038: val_loss did not improve from 0.00077
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0014 - val_loss: 9.4094e-04
# Epoch 39/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00039: val_loss improved from 0.00077 to 0.00069, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 5s 85ms/step - loss: 0.0012 - val_loss: 6.9308e-04
# Epoch 40/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00040: val_loss did not improve from 0.00069
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 41/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00041: val_loss did not improve from 0.00069
# 56/56 [==============================] - 4s 79ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 42/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00042: val_loss did not improve from 0.00069
# 56/56 [==============================] - 4s 78ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 43/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00043: val_loss did not improve from 0.00069
# 56/56 [==============================] - 5s 87ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 44/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00044: val_loss improved from 0.00069 to 0.00063, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 5s 95ms/step - loss: 0.0013 - val_loss: 6.2712e-04
# Epoch 45/70
# 56/56 [==============================] - ETA: 0s - loss: 9.5716e-04
# Epoch 00045: val_loss did not improve from 0.00063
# 56/56 [==============================] - 5s 90ms/step - loss: 9.5716e-04 - val_loss: 0.0021
# Epoch 46/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00046: val_loss did not improve from 0.00063
# 56/56 [==============================] - 5s 82ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 47/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00047: val_loss did not improve from 0.00063
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0011 - val_loss: 8.0672e-04
# Epoch 48/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00048: val_loss did not improve from 0.00063
# 56/56 [==============================] - 4s 80ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 49/70
# 56/56 [==============================] - ETA: 0s - loss: 9.9103e-04
# Epoch 00049: val_loss did not improve from 0.00063
# 56/56 [==============================] - 4s 78ms/step - loss: 9.9103e-04 - val_loss: 6.7289e-04
# Epoch 50/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00050: val_loss did not improve from 0.00063
# 56/56 [==============================] - 5s 81ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 51/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00051: val_loss did not improve from 0.00063
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 52/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00052: val_loss did not improve from 0.00063
# 56/56 [==============================] - 5s 97ms/step - loss: 0.0012 - val_loss: 6.3647e-04
# Epoch 53/70
# 56/56 [==============================] - ETA: 0s - loss: 9.9430e-04
# Epoch 00053: val_loss improved from 0.00063 to 0.00059, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 6s 110ms/step - loss: 9.9430e-04 - val_loss: 5.9475e-04
# Epoch 54/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 00054: val_loss improved from 0.00059 to 0.00059, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 5s 96ms/step - loss: 0.0010 - val_loss: 5.8849e-04
# Epoch 55/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 00055: val_loss did not improve from 0.00059
# 56/56 [==============================] - 5s 91ms/step - loss: 0.0010 - val_loss: 0.0028
# Epoch 56/70
# 56/56 [==============================] - ETA: 0s - loss: 9.2464e-04
# Epoch 00056: val_loss did not improve from 0.00059
# 56/56 [==============================] - 5s 87ms/step - loss: 9.2464e-04 - val_loss: 6.2256e-04
# Epoch 57/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 00057: val_loss did not improve from 0.00059
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0010 - val_loss: 9.4374e-04
# Epoch 58/70
# 56/56 [==============================] - ETA: 0s - loss: 9.0846e-04
# Epoch 00058: val_loss improved from 0.00059 to 0.00057, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 79ms/step - loss: 9.0846e-04 - val_loss: 5.6664e-04
# Epoch 59/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00059: val_loss did not improve from 0.00057
# 56/56 [==============================] - 4s 74ms/step - loss: 0.0011 - val_loss: 8.1053e-04
# Epoch 60/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 00060: val_loss did not improve from 0.00057
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 61/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00061: val_loss did not improve from 0.00057
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 62/70
# 56/56 [==============================] - ETA: 0s - loss: 8.9774e-04
# Epoch 00062: val_loss did not improve from 0.00057
# 56/56 [==============================] - 4s 75ms/step - loss: 8.9774e-04 - val_loss: 6.0501e-04
# Epoch 63/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 00063: val_loss did not improve from 0.00057
# 56/56 [==============================] - 4s 76ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 64/70
# 56/56 [==============================] - ETA: 0s - loss: 9.2050e-04
# Epoch 00064: val_loss improved from 0.00057 to 0.00054, saving model to tesla.stock_prediction.hdf5
# 56/56 [==============================] - 4s 76ms/step - loss: 9.2050e-04 - val_loss: 5.4071e-04
# Epoch 65/70
# 56/56 [==============================] - ETA: 0s - loss: 8.6770e-04
# Epoch 00065: val_loss did not improve from 0.00054
# 56/56 [==============================] - 5s 83ms/step - loss: 8.6770e-04 - val_loss: 5.5651e-04
# Epoch 66/70
# 56/56 [==============================] - ETA: 0s - loss: 9.0402e-04
# Epoch 00066: val_loss did not improve from 0.00054
# 56/56 [==============================] - 5s 91ms/step - loss: 9.0402e-04 - val_loss: 9.8975e-04
# Epoch 67/70
# 56/56 [==============================] - ETA: 0s - loss: 8.6697e-04
# Epoch 00067: val_loss did not improve from 0.00054
# 56/56 [==============================] - 4s 80ms/step - loss: 8.6697e-04 - val_loss: 0.0013
# Epoch 68/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 00068: val_loss did not improve from 0.00054
# 56/56 [==============================] - 5s 84ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 69/70
# 56/56 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 00069: val_loss did not improve from 0.00054
# 56/56 [==============================] - 5s 96ms/step - loss: 0.0010 - val_loss: 5.6246e-04
# Epoch 70/70
# 56/56 [==============================] - ETA: 0s - loss: 8.8173e-04
# Epoch 00070: val_loss did not improve from 0.00054
# 56/56 [==============================] - 6s 100ms/step - loss: 8.8173e-04 - val_loss: 9.8773e-04

# %%
model = load_model('tesla.stock_prediction.hdf5')

# %% [markdown]
# Best model saved as 'tesla.stock_prediction.hdf5'
# ## Visualizing Results
# Plotting the Predicted Stock Price with True Stock Price

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

fig, ax = plt.subplots(figsize=(35,10))
plt.plot(df, color='red',  label="True Stock Price",)
ax.plot(range(len(y_train)+50,len(y_train)+50+len(predictions)),predictions, color='blue', label='Predicted Stock Price')
plt.legend()

# %%
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))


fig, ax = plt.subplots(figsize=(35,10))
ax.plot(y_test_scaled, color='red', label='True Stock Price')
plt.plot(predictions, color='blue', label='Predicted Stock Price')
plt.legend()

# %% [markdown]
# ## Evaluation

# %%
df1.reset_index(inplace=True)
comparison = df1[['Date','Open']].iloc[len(y_train)+50:] 
comparison['Predictions'] = predictions

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(comparison['Open'],comparison['Predictions'])
# Out:
# 1.9977664235221895
